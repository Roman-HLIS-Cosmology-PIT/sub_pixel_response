# %%
import numpy as np

# %% [markdown]
# This notebook is used to test out the coordinate mappings to help with running all the SCA's and creating simulated images for each of them. In order to do this, we have to match each SCA with the correct SCACEN with respect to the WFICEN. They each need to have the correct coordinate systems when making images for each of them.
#
# I think they also need to have the correct PSF's and scaling, but this may be discussed later.
#
# I want to start out with going cell by cell focusing on each SCA, then writing them out all together in one cell later per chance.

# %%
# For SCA 1

R_1 = np.array(
    [
        [0.999999315634242, 0.000000756773992, -0.001169927550709],
        [0.000000000000000, 0.999999790789090, 0.000646855297397],
        [0.001169927795471, -0.000646854854711, 0.999999106423476],
    ]
)

delta_1 = np.arctan2(R_1[2, 2], np.hypot(R_1[2, 0], R_1[2, 1]))
alpha_1 = np.arctan2(R_1[2, 1], R_1[2, 0]) + 2 * np.pi
s_1 = R_1 @ np.array(
    [-np.sin(delta_1) * np.cos(alpha_1), -np.sin(delta_1) * np.sin(alpha_1), np.cos(delta_1)]
)
phi_1 = np.arctan2(-s_1[0], s_1[1])

print("SCA 1")
print(f"  alpha = {alpha_1:.8f} rad = {np.degrees(alpha_1):.6f} deg")
print(f"  delta = {delta_1:.8f} rad = {np.degrees(delta_1):.6f} deg")
print(f"  phi   = {phi_1:.8f} rad = {np.degrees(phi_1):.6f} deg")

# %%
# For SCA 2

R_2 = np.array(
    [
        [0.999999317472245, -0.000002226814009, -0.001168353578692],
        [0.000000000000000, 0.999998183697735, -0.001905938412203],
        [0.001168355700780, 0.001905937111347, 0.999997501171220],
    ]
)

delta_2 = np.arctan2(R_2[2, 2], np.hypot(R_2[2, 0], R_2[2, 1]))
alpha_2 = np.arctan2(R_2[2, 1], R_2[2, 0])
s_2 = R_2 @ np.array(
    [-np.sin(delta_2) * np.cos(alpha_2), -np.sin(delta_2) * np.sin(alpha_2), np.cos(delta_2)]
)
phi_2 = np.arctan2(-s_2[0], s_2[1])

print("SCA 2")
print(f"  alpha = {alpha_2:.8f} rad = {np.degrees(alpha_2):.6f} deg")
print(f"  delta = {delta_2:.8f} rad = {np.degrees(delta_2):.6f} deg")
print(f"  phi   = {phi_2:.8f} rad = {np.degrees(phi_2):.6f} deg")

# %%
# For SCA 3

R_3 = np.array(
    [
        [0.999999320647781, -0.000004882749786, -0.001165624354528],
        [0.000000000000000, 0.999991226436935, -0.004188919807704],
        [0.001165634581296, 0.004188916961952, 0.999990547090676],
    ]
)

delta_3 = np.arctan2(R_3[2, 2], np.hypot(R_3[2, 0], R_3[2, 1]))
alpha_3 = np.arctan2(R_3[2, 1], R_3[2, 0])
s_3 = R_3 @ np.array(
    [-np.sin(delta_3) * np.cos(alpha_3), -np.sin(delta_3) * np.sin(alpha_3), np.cos(delta_3)]
)
phi_3 = np.arctan2(-s_3[0], s_3[1])

print("SCA 3")
print(f"  alpha = {alpha_3:.8f} rad = {np.degrees(alpha_3):.6f} deg")
print(f"  delta = {delta_3:.8f} rad = {np.degrees(delta_3):.6f} deg")
print(f"  phi   = {phi_3:.8f} rad = {np.degrees(phi_3):.6f} deg")

# %%
# For SCA 4

R_4 = np.array(
    [
        [0.999993746083975, 0.000003956266759, -0.003536633609215],
        [0.000000000000000, 0.999999374308016, 0.001118652572210],
        [0.003536635822060, -0.001118645576250, 0.999993120395904],
    ]
)

delta_4 = np.arctan2(R_4[2, 2], np.hypot(R_4[2, 0], R_4[2, 1]))
alpha_4 = np.arctan2(R_4[2, 1], R_4[2, 0]) + 2 * np.pi
s_4 = R_4 @ np.array(
    [-np.sin(delta_4) * np.cos(alpha_4), -np.sin(delta_4) * np.sin(alpha_4), np.cos(delta_4)]
)
phi_4 = np.arctan2(-s_4[0], s_4[1])

print("SCA 4")
print(f"  alpha = {alpha_4:.8f} rad = {np.degrees(alpha_4):.6f} deg")
print(f"  delta = {delta_4:.8f} rad = {np.degrees(delta_4):.6f} deg")
print(f"  phi   = {phi_4:.8f} rad = {np.degrees(phi_4):.6f} deg")

# %%
# For SCA 5

R_5 = np.array(
    [
        [0.999993743280690, -0.000005092637341, -0.003537424704405],
        [0.000000000000000, 0.999998963712116, -0.001439643947090],
        [0.003537428370199, 0.001439634939641, 0.999992706999289],
    ]
)

delta_5 = np.arctan2(R_5[2, 2], np.hypot(R_5[2, 0], R_5[2, 1]))
alpha_5 = np.arctan2(R_5[2, 1], R_5[2, 0])
s_5 = R_5 @ np.array(
    [-np.sin(delta_5) * np.cos(alpha_5), -np.sin(delta_5) * np.sin(alpha_5), np.cos(delta_5)]
)
phi_5 = np.arctan2(-s_5[0], s_5[1])

print("SCA 5")
print(f"  alpha = {alpha_5:.8f} rad = {np.degrees(alpha_5):.6f} deg")
print(f"  delta = {delta_5:.8f} rad = {np.degrees(delta_5):.6f} deg")
print(f"  phi   = {phi_5:.8f} rad = {np.degrees(phi_5):.6f} deg")

# %%
# For SCA 6

R_6 = np.array(
    [
        [0.999993753496664, -0.000013138707319, -0.003534514821982],
        [0.000000000000000, 0.999993091064063, -0.003717233398632],
        [0.003534539241888, 0.003717210178921, 0.999986844603884],
    ]
)

delta_6 = np.arctan2(R_6[2, 2], np.hypot(R_6[2, 0], R_6[2, 1]))
alpha_6 = np.arctan2(R_6[2, 1], R_6[2, 0])
s_6 = R_6 @ np.array(
    [-np.sin(delta_6) * np.cos(alpha_6), -np.sin(delta_6) * np.sin(alpha_6), np.cos(delta_6)]
)
phi_6 = np.arctan2(-s_6[0], s_6[1])

print("SCA 6")
print(f"  alpha = {alpha_6:.8f} rad = {np.degrees(alpha_6):.6f} deg")
print(f"  delta = {delta_6:.8f} rad = {np.degrees(delta_6):.6f} deg")
print(f"  phi   = {phi_6:.8f} rad = {np.degrees(phi_6):.6f} deg")

# %%
# For SCA 7

R_7 = np.array(
    [
        [0.999982604926478, 0.000013348076824, -0.005898276552062],
        [0.000000000000000, 0.999997439319063, 0.002263041165692],
        [0.005898291655705, -0.002263001799924, 0.999980044290084],
    ]
)

delta_7 = np.arctan2(R_7[2, 2], np.hypot(R_7[2, 0], R_7[2, 1]))
alpha_7 = np.arctan2(R_7[2, 1], R_7[2, 0]) + 2 * np.pi
s_7 = R_7 @ np.array(
    [-np.sin(delta_7) * np.cos(alpha_7), -np.sin(delta_7) * np.sin(alpha_7), np.cos(delta_7)]
)
phi_7 = np.arctan2(-s_7[0], s_7[1])

print("SCA 7")
print(f"  alpha = {alpha_7:.8f} rad = {np.degrees(alpha_7):.6f} deg")
print(f"  delta = {delta_7:.8f} rad = {np.degrees(delta_7):.6f} deg")
print(f"  phi   = {phi_7:.8f} rad = {np.degrees(phi_7):.6f} deg")

# %%
# For SCA 8

R_8 = np.array(
    [
        [0.999982580295055, -0.000001820634454, -0.005902465851664],
        [0.000000000000000, 0.999999952428316, -0.000308453180996],
        [0.005902466132454, 0.000308447807832, 0.999982532724200],
    ]
)

delta_8 = np.arctan2(R_8[2, 2], np.hypot(R_8[2, 0], R_8[2, 1]))
alpha_8 = np.arctan2(R_8[2, 1], R_8[2, 0])
s_8 = R_8 @ np.array(
    [-np.sin(delta_8) * np.cos(alpha_8), -np.sin(delta_8) * np.sin(alpha_8), np.cos(delta_8)]
)
phi_8 = np.arctan2(-s_8[0], s_8[1])

print("SCA 8")
print(f"  alpha = {alpha_8:.8f} rad = {np.degrees(alpha_8):.6f} deg")
print(f"  delta = {delta_8:.8f} rad = {np.degrees(delta_8):.6f} deg")
print(f"  phi   = {phi_8:.8f} rad = {np.degrees(phi_8):.6f} deg")

# %%
# For SCA 9

R_9 = np.array(
    [
        [0.999982474526266, -0.000015200040292, -0.005920338612335],
        [0.000000000000000, 0.999996704174254, -0.002567419060041],
        [0.005920358124804, 0.002567374064805, 0.999979178758281],
    ]
)

delta_9 = np.arctan2(R_9[2, 2], np.hypot(R_9[2, 0], R_9[2, 1]))
alpha_9 = np.arctan2(R_9[2, 1], R_9[2, 0])
s_9 = R_9 @ np.array(
    [-np.sin(delta_9) * np.cos(alpha_9), -np.sin(delta_9) * np.sin(alpha_9), np.cos(delta_9)]
)
phi_9 = np.arctan2(-s_9[0], s_9[1])

print("SCA 9")
print(f"  alpha = {alpha_9:.8f} rad = {np.degrees(alpha_9):.6f} deg")
print(f"  delta = {delta_9:.8f} rad = {np.degrees(delta_9):.6f} deg")
print(f"  phi   = {phi_9:.8f} rad = {np.degrees(phi_9):.6f} deg")

# %%
# For SCA 10

R_10 = np.array(
    [
        [0.999999281495090, -0.000000776459662, 0.001198752977111],
        [0.000000000000000, 0.999999790227638, 0.000647722686919],
        [-0.001198753228576, -0.000647722221527, 0.999999071722879],
    ]
)

delta_10 = np.arctan2(R_10[2, 2], np.hypot(R_10[2, 0], R_10[2, 1]))
alpha_10 = np.arctan2(R_10[2, 1], R_10[2, 0]) + 2 * np.pi
s_10 = R_10 @ np.array(
    [-np.sin(delta_10) * np.cos(alpha_10), -np.sin(delta_10) * np.sin(alpha_10), np.cos(delta_10)]
)
phi_10 = np.arctan2(-s_10[0], s_10[1]) + 2 * np.pi

print("SCA 10")
print(f"  alpha = {alpha_10:.8f} rad = {np.degrees(alpha_10):.6f} deg")
print(f"  delta = {delta_10:.8f} rad = {np.degrees(delta_10):.6f} deg")
print(f"  phi   = {phi_10:.8f} rad = {np.degrees(phi_10):.6f} deg")

# %%
# For SCA 11

R_11 = np.array(
    [
        [0.999999281469882, 0.000002283730509, 0.001198772081556],
        [0.000000000000000, 0.999998185381686, -0.001905054680476],
        [-0.001198774256874, 0.001905053311637, 0.999997466852872],
    ]
)

delta_11 = np.arctan2(R_11[2, 2], np.hypot(R_11[2, 0], R_11[2, 1]))
alpha_11 = np.arctan2(R_11[2, 1], R_11[2, 0])
s_11 = R_11 @ np.array(
    [-np.sin(delta_11) * np.cos(alpha_11), -np.sin(delta_11) * np.sin(alpha_11), np.cos(delta_11)]
)
phi_11 = np.arctan2(-s_11[0], s_11[1]) + 2 * np.pi

print("SCA 11")
print(f"  alpha = {alpha_11:.8f} rad = {np.degrees(alpha_11):.6f} deg")
print(f"  delta = {delta_11:.8f} rad = {np.degrees(delta_11):.6f} deg")
print(f"  phi   = {phi_11:.8f} rad = {np.degrees(phi_11):.6f} deg")

# %%
# For SCA 12

R_12 = np.array(
    [
        [0.999999283066333, 0.000005014914020, 0.001197431279904],
        [0.000000000000000, 0.999991230192174, -0.004188023250054],
        [-0.001197441781239, 0.004188020247519, 0.999990513264794],
    ]
)

delta_12 = np.arctan2(R_12[2, 2], np.hypot(R_12[2, 0], R_12[2, 1]))
alpha_12 = np.arctan2(R_12[2, 1], R_12[2, 0])
s_12 = R_12 @ np.array(
    [-np.sin(delta_12) * np.cos(alpha_12), -np.sin(delta_12) * np.sin(alpha_12), np.cos(delta_12)]
)
phi_12 = np.arctan2(-s_12[0], s_12[1]) + 2 * np.pi

print("SCA 12")
print(f"  alpha = {alpha_12:.8f} rad = {np.degrees(alpha_12):.6f} deg")
print(f"  delta = {delta_12:.8f} rad = {np.degrees(delta_12):.6f} deg")
print(f"  phi   = {phi_12:.8f} rad = {np.degrees(phi_12):.6f} deg")

# %%
# For SCA 13

R_13 = np.array(
    [
        [0.999993645162039, -0.000003997295552, 0.003565055337604],
        [0.000000000000000, 0.999999371406965, 0.001121242915054],
        [-0.003565057578574, -0.001121235789737, 0.999993016572999],
    ]
)

delta_13 = np.arctan2(R_13[2, 2], np.hypot(R_13[2, 0], R_13[2, 1]))
alpha_13 = np.arctan2(R_13[2, 1], R_13[2, 0]) + 2 * np.pi
s_13 = R_13 @ np.array(
    [-np.sin(delta_13) * np.cos(alpha_13), -np.sin(delta_13) * np.sin(alpha_13), np.cos(delta_13)]
)
phi_13 = np.arctan2(-s_13[0], s_13[1]) + 2 * np.pi

print("SCA 13")
print(f"  alpha = {alpha_13:.8f} rad = {np.degrees(alpha_13):.6f} deg")
print(f"  delta = {delta_13:.8f} rad = {np.degrees(delta_13):.6f} deg")
print(f"  phi   = {phi_13:.8f} rad = {np.degrees(phi_13):.6f} deg")

# %%
# For SCA 14

R_14 = np.array(
    [
        [0.999993636610722, 0.000005126438086, 0.003567451721251],
        [0.000000000000000, 0.999998967513086, -0.001437001309005],
        [-0.003567455404602, 0.001436992164806, 0.999992604130378],
    ]
)

delta_14 = np.arctan2(R_14[2, 2], np.hypot(R_14[2, 0], R_14[2, 1]))
alpha_14 = np.arctan2(R_14[2, 1], R_14[2, 0])
s_14 = R_14 @ np.array(
    [-np.sin(delta_14) * np.cos(alpha_14), -np.sin(delta_14) * np.sin(alpha_14), np.cos(delta_14)]
)
phi_14 = np.arctan2(-s_14[0], s_14[1]) + 2 * np.pi

print("SCA 14")
print(f"  alpha = {alpha_14:.8f} rad = {np.degrees(alpha_14):.6f} deg")
print(f"  delta = {delta_14:.8f} rad = {np.degrees(delta_14):.6f} deg")
print(f"  phi   = {phi_14:.8f} rad = {np.degrees(phi_14):.6f} deg")

# %%
# For SCA 15

R_15 = np.array(
    [
        [0.999993641945108, 0.000013245932714, 0.003565935207391],
        [0.000000000000000, 0.999993101038782, -0.003714549076386],
        [-0.003565959808809, 0.003714525459079, 0.999986743027754],
    ]
)

delta_15 = np.arctan2(R_15[2, 2], np.hypot(R_15[2, 0], R_15[2, 1]))
alpha_15 = np.arctan2(R_15[2, 1], R_15[2, 0])
s_15 = R_15 @ np.array(
    [-np.sin(delta_15) * np.cos(alpha_15), -np.sin(delta_15) * np.sin(alpha_15), np.cos(delta_15)]
)
phi_15 = np.arctan2(-s_15[0], s_15[1]) + 2 * np.pi

print("SCA 15")
print(f"  alpha = {alpha_15:.8f} rad = {np.degrees(alpha_15):.6f} deg")
print(f"  delta = {delta_15:.8f} rad = {np.degrees(delta_15):.6f} deg")
print(f"  phi   = {phi_15:.8f} rad = {np.degrees(phi_15):.6f} deg")

# %%
# For SCA 16

R_16 = np.array(
    [
        [0.999982442445639, -0.000013435585461, 0.005925759018026],
        [0.000000000000000, 0.999997429642397, 0.002267313079374],
        [-0.005925774249385, -0.002267273270902, 0.999979872133165],
    ]
)

delta_16 = np.arctan2(R_16[2, 2], np.hypot(R_16[2, 0], R_16[2, 1]))
alpha_16 = np.arctan2(R_16[2, 1], R_16[2, 0]) + 2 * np.pi
s_16 = R_16 @ np.array(
    [-np.sin(delta_16) * np.cos(alpha_16), -np.sin(delta_16) * np.sin(alpha_16), np.cos(delta_16)]
)
phi_16 = np.arctan2(-s_16[0], s_16[1]) + 2 * np.pi

print("SCA 16")
print(f"  alpha = {alpha_16:.8f} rad = {np.degrees(alpha_16):.6f} deg")
print(f"  delta = {delta_16:.8f} rad = {np.degrees(delta_16):.6f} deg")
print(f"  phi   = {phi_16:.8f} rad = {np.degrees(phi_16):.6f} deg")

# %%
# For SCA 17

R_17 = np.array(
    [
        [0.999982408009136, 0.000001803740908, 0.005931582335042],
        [0.000000000000000, 0.999999953764330, -0.000304091003477],
        [-0.005931582609293, 0.000304085653911, 0.999982361774279],
    ]
)

delta_17 = np.arctan2(R_17[2, 2], np.hypot(R_17[2, 0], R_17[2, 1]))
alpha_17 = np.arctan2(R_17[2, 1], R_17[2, 0])
s_17 = R_17 @ np.array(
    [-np.sin(delta_17) * np.cos(alpha_17), -np.sin(delta_17) * np.sin(alpha_17), np.cos(delta_17)]
)
phi_17 = np.arctan2(-s_17[0], s_17[1]) + 2 * np.pi

print("SCA 17")
print(f"  alpha = {alpha_17:.8f} rad = {np.degrees(alpha_17):.6f} deg")
print(f"  delta = {delta_17:.8f} rad = {np.degrees(delta_17):.6f} deg")
print(f"  phi   = {phi_17:.8f} rad = {np.degrees(phi_17):.6f} deg")

# %%
# For SCA 18

R_18 = np.array(
    [
        [0.999982293396816, 0.000015251910148, 0.005950853739057],
        [0.000000000000000, 0.999996715586803, -0.002562970075082],
        [-0.005950873284184, 0.002562924693588, 0.999979009041775],
    ]
)

delta_18 = np.arctan2(R_18[2, 2], np.hypot(R_18[2, 0], R_18[2, 1]))
alpha_18 = np.arctan2(R_18[2, 1], R_18[2, 0])
s_18 = R_18 @ np.array(
    [-np.sin(delta_18) * np.cos(alpha_18), -np.sin(delta_18) * np.sin(alpha_18), np.cos(delta_18)]
)
phi_18 = np.arctan2(-s_18[0], s_18[1]) + 2 * np.pi

print("SCA 18")
print(f"  alpha = {alpha_18:.8f} rad = {np.degrees(alpha_18):.6f} deg")
print(f"  delta = {delta_18:.8f} rad = {np.degrees(delta_18):.6f} deg")
print(f"  phi   = {phi_18:.8f} rad = {np.degrees(phi_18):.6f} deg")

# %% [markdown]
# Next, I will do everything that I did above all in one code cell. I want to figure out how to do this to put in my python file when I run all the SCAs. I think we will have to define the arrays by SCA number. This will make it easier when calculating the alpha, delta, and phi for each SCA coordinate systems.

# %%
def r_sca(sca_number):
    """
    Get the rotation matrix for a given SCA number.

    Parameters:
    ----------
    sca_number : int
        SCA number (1 to 18).

    Returns
    -------
    np.ndarray
        3x3 rotation matrix.
    """
    R_matrices = {
        1: np.array(
            [
                [0.999999315634242, 0.000000756773992, -0.001169927550709],
                [0.000000000000000, 0.999999790789090, 0.000646855297397],
                [0.001169927795471, -0.000646854854711, 0.999999106423476],
            ]
        ),
        2: np.array(
            [
                [0.999999317472245, -0.000002226814009, -0.001168353578692],
                [0.000000000000000, 0.999998183697735, -0.001905938412203],
                [0.001168355700780, 0.001905937111347, 0.999997501171220],
            ]
        ),
        3: np.array(
            [
                [0.999999320647781, -0.000004882749786, -0.001165624354528],
                [0.000000000000000, 0.999991226436935, -0.004188919807704],
                [0.001165634581296, 0.004188916961952, 0.999990547090676],
            ]
        ),
        4: np.array(
            [
                [0.999993746083975, 0.000003956266759, -0.003536633609215],
                [0.000000000000000, 0.999999374308016, 0.001118652572210],
                [0.003536635822060, -0.001118645576250, 0.999993120395904],
            ]
        ),
        5: np.array(
            [
                [0.999993743280690, -0.000005092637341, -0.003537424704405],
                [0.000000000000000, 0.999998963712116, -0.001439643947090],
                [0.003537428370199, 0.001439634939641, 0.999992706999289],
            ]
        ),
        6: np.array(
            [
                [0.999993753496664, -0.000013138707319, -0.003534514821982],
                [0.000000000000000, 0.999993091064063, -0.003717233398632],
                [0.003534539241888, 0.003717210178921, 0.999986844603884],
            ]
        ),
        7: np.array(
            [
                [0.999982604926478, 0.000013348076824, -0.005898276552062],
                [0.000000000000000, 0.999997439319063, 0.002263041165692],
                [0.005898291655705, -0.002263001799924, 0.999980044290084],
            ]
        ),
        8: np.array(
            [
                [0.999982580295055, -0.000001820634454, -0.005902465851664],
                [0.000000000000000, 0.999999952428316, -0.000308453180996],
                [0.005902466132454, 0.000308447807832, 0.999982532724200],
            ]
        ),
        9: np.array(
            [
                [0.999982474526266, -0.000015200040292, -0.005920338612335],
                [0.000000000000000, 0.999996704174254, -0.002567419060041],
                [0.005920358124804, 0.002567374064805, 0.999979178758281],
            ]
        ),
        10: np.array(
            [
                [0.999999281495090, -0.000000776459662, 0.001198752977111],
                [0.000000000000000, 0.999999790227638, 0.000647722686919],
                [-0.001198753228576, -0.000647722221527, 0.999999071722879],
            ]
        ),
        11: np.array(
            [
                [0.999999281469882, 0.000002283730509, 0.001198772081556],
                [0.000000000000000, 0.999998185381686, -0.001905054680476],
                [-0.001198774256874, 0.001905053311637, 0.999997466852872],
            ]
        ),
        12: np.array(
            [
                [0.999999283066333, 0.000005014914020, 0.001197431279904],
                [0.000000000000000, 0.999991230192174, -0.004188023250054],
                [-0.001197441781239, 0.004188020247519, 0.999990513264794],
            ]
        ),
        13: np.array(
            [
                [0.999993645162039, -0.000003997295552, 0.003565055337604],
                [0.000000000000000, 0.999999371406965, 0.001121242915054],
                [-0.003565057578574, -0.001121235789737, 0.999993016572999],
            ]
        ),
        14: np.array(
            [
                [0.999993636610722, 0.000005126438086, 0.003567451721251],
                [0.000000000000000, 0.999998967513086, -0.001437001309005],
                [-0.003567455404602, 0.001436992164806, 0.999992604130378],
            ]
        ),
        15: np.array(
            [
                [0.999993641945108, 0.000013245932714, 0.003565935207391],
                [0.000000000000000, 0.999993101038782, -0.003714549076386],
                [-0.003565959808809, 0.003714525459079, 0.999986743027754],
            ]
        ),
        16: np.array(
            [
                [0.999982442445639, -0.000013435585461, 0.005925759018026],
                [0.000000000000000, 0.999997429642397, 0.002267313079374],
                [-0.005925774249385, -0.002267273270902, 0.999979872133165],
            ]
        ),
        17: np.array(
            [
                [0.999982408009136, 0.000001803740908, 0.005931582335042],
                [0.000000000000000, 0.999999953764330, -0.000304091003477],
                [-0.005931582609293, 0.000304085653911, 0.999982361774279],
            ]
        ),
        18: np.array(
            [
                [0.999982293396816, 0.000015251910148, 0.005950853739057],
                [0.000000000000000, 0.999996715586803, -0.002562970075082],
                [-0.005950873284184, 0.002562924693588, 0.999979009041775],
            ]
        ),
    }

    return R_matrices.get(sca_number)

# %%
def euler_angle_conversion(R):
    """
    Convert a rotation matrix to Euler angles (alpha, delta, phi).

    Parameters:
    ----------
    R : np.ndarray
        3x3 rotation matrix.

    Returns
    -------
    tuple
        Euler angles (alpha, delta, phi) in radians.
    """
    delta = np.arctan2(R[2, 2], np.hypot(R[2, 0], R[2, 1]))
    alpha = np.arctan2(R[2, 1], R[2, 0])
    s = R @ np.array([-np.sin(delta) * np.cos(alpha), -np.sin(delta) * np.sin(alpha), np.cos(delta)])
    phi = np.arctan2(-s[0], s[1]) + 2 * np.pi
    return alpha, delta, phi

# %%
for sca_number in range(1, 19):
    R = r_sca(sca_number)
    if R is not None:
        alpha, delta, phi = euler_angle_conversion(R)
        if alpha < 1:
            alpha = alpha + 2 * np.pi
        if delta < 1:
            delta = delta + 2 * np.pi
        if phi < 1:
            phi = phi + 2 * np.pi

        print(f"SCA {sca_number}")
        print(f"  alpha = {alpha:.8f} rad = {np.degrees(alpha):.6f} deg")
        print(f"  delta = {delta:.8f} rad = {np.degrees(delta):.6f} deg")
        print(f"  phi   = {phi:.8f} rad = {np.degrees(phi):.6f} deg")
    else:
        print(f"SCA {sca_number}: Rotation matrix not found.")

# %% [markdown]
# Now we need to do some hardcore debugging for run_all_scas.py

# %%
from pathlib import Path

import yaml
import numpy as np
from sub_pixel_response.imagesim import run_simulation

# %%
image_dir = Path("all_scas")
config_dir = Path("all_scas_configs")

image_dir.mkdir(exist_ok=True)
config_dir.mkdir(exist_ok=True)

new_config = "/users/PAS2340/karadiludovico/sub_pixel_response/scripts/run_all_scas/example_test.yaml"

with open(new_config) as f:
    base_config = yaml.safe_load(f)

for sca in [1, 2]:
    print(f"Running SCA {sca}")

    # Getting the rotation matrix R for each SCA
    R = r_sca(sca)

    if R is None:
        print(f"No rotation matrix found for SCA {sca}, skipping.")
        continue

    # Converting rotation matrix R to Euler angles (alpha, delta, phi)
    alpha, delta, phi = euler_angle_conversion(R)

    if alpha < 0:
        alpha = alpha + 2 * np.pi

    if delta < 0:
        delta = delta + 2 * np.pi

    if phi < 0:
        phi = phi + 2 * np.pi

    outfile = image_dir / f"roman_sca_{sca:02d}.fits"

    # Skip SCAs that are already finished
    if outfile.exists() and outfile.stat().st_size > 0:
        print(f"{outfile} already exists, skipping SCA {sca}")
        continue

    config = base_config.copy()

    config["SCA"] = sca
    config["outFile"] = str(image_dir / f"roman_sca_{sca:02d}.fits")

    distortion_headers = [
        {
            "CD1_1": 3.063655969174577e-05,
            "CD1_2": 9.817349061260638e-08,
            "CD2_1": -7.736607055065377e-08,
            "CD2_2": -3.005506116767925e-05,
            "A_ORDER": 4,
            "B_ORDER": 4,
            "A_0_2": -2.692540120370307e-12,
            "B_0_2": -5.848189693658369e-11,
            "A_0_3": -1.548311386787218e-17,
            "B_0_3": 1.131320460043020e-15,
            "A_0_4": 2.881347101785209e-22,
            "B_0_4": 5.369119265587527e-21,
            "A_1_1": 4.000473978686269e-11,
            "B_1_1": 5.461352641809087e-12,
            "A_1_2": -1.232914133049007e-15,
            "B_1_2": 4.387528517521882e-17,
            "A_1_3": -7.729415683073430e-21,
            "B_1_3": -7.240379227019442e-22,
            "A_2_0": -8.844241123721483e-12,
            "B_2_0": -2.000034273037264e-11,
            "A_2_1": -4.691456837209364e-17,
            "B_2_1": 1.233404236197323e-15,
            "A_2_2": 1.315811627662120e-21,
            "B_2_2": 1.152119700114587e-20,
            "A_3_0": -1.336479658416659e-15,
            "B_3_0": 1.509626294142354e-17,
            "A_3_1": -5.730085671648335e-21,
            "B_3_1": -8.759510402470403e-22,
            "A_4_0": 1.161637437034518e-21,
            "B_4_0": 1.214538284362193e-20,
        },
        {
            "CD1_1": 3.041058491098337e-05,
            "CD1_2": 1.243335110861408e-07,
            "CD2_1": -1.037635755627832e-07,
            "CD2_2": -2.940113767578835e-05,
            "A_ORDER": 4,
            "B_ORDER": 4,
            "A_0_2":
-05,
            "A_ORDER": 4,
            "B_ORDER": 4,
            "A_0_2": 1.312568259018621e-11,
            "B_0_2": -6.353184479891348e-11,
            "A_0_3": 7.772211782372379e-17,
            "B_0_3": 1.050741435902491e-15,
            "A_0_4": -7.466038723658760e-22,
            "B_0_4": 4.867627659463334e-21,
            "A_1_1": 4.195386811215749e-11,
            "B_1_1": -2.629546560242113e-11,
            "A_1_2": -1.127862672187130e-15,
            "B_1_2": -2.366323353508677e-16,
            "A_1_3": -7.036927848716508e-21,
            "B_1_3": 3.167341212833479e-21,
            "A_2_0": 4.306018992258922e-11,
            "B_2_0": -2.094110148415912e-11,
            "A_2_1": 2.443800380614287e-16,
            "B_2_1": 1.128502685118011e-15,
            "A_2_2": -5.856250661235152e-21,
            "B_2_2": 8.294930215207772e-21,
            "A_3_0": -1.191248417581102e-15,
            "B_3_0": -8.218002924054029e-17,
            "A_3_1": -5.742167441480328e-21,
            "B_3_1": 3.976243083844590e-21,
            "A_4_0": -5.775861996688285e-21,
            "B_4_0": 4.867627659463334e-21,
        },
        {
            "CD1_1": 2.986926106648360e-05,
            "CD1_2": -5.962032510015921e-07,
            "CD2_1": 6.153541421549009e-07,
            "CD2_2": -2.905508295466651e-05,
            "A_ORDER": 4,
            "B_ORDER": 4,
            "A_0_2": 1.212486224059388e-11,
            "B_0_2": -7.647485950176695e-11,
            "A_0_3": 9.044731627765341e-17,
            "B_0_3": 8.961068208683935e-16,
            "A_0_4": -4.960107114228583e-22,
            "B_0_4": 7.116378178920369e-21,
            "A_1_1": 5.146871936287581e-11,
            "B_1_1": -2.427945508010969e-11,
            "A_1_2": -1.033714611799903e-15,
            "B_1_2": -2.746296257342669e-16,
            "A_1_3": -9.395992114460307e-21,
            "B_1_3": 2.195748646678780e-21,
            "A_2_0": 4.227572966439868e-11,
            "B_2_0": -2.568401225784281e-11,
            "A_2_1": 2.945514599945405e-16,
            "B_2_1": 1.034411223513199e-15,
            "A_2_2": -4.920315614182770e-21,
            "B_2_2": 1.090107319801723e-20,
            "A_3_0": -1.157938161191402e-15,
            "B_3_0": -9.882153493662191e-17,
            "A_3_1": -5.909915350748943e-21,
            "B_3_1": 3.271210852617556e-21,
            "A_4_0": -5.525268835745266e-21,
            "B_4_0": 1.050450996793757e-20,
        },
    ]

    config.update(distortion_headers[sca - 1])

    # Adding SCA specific rotation angles to the config
    config["raCen"] = float(alpha)
    config["decCen"] = float(delta)
    config["LONPOLE"] = float(phi)

    print("RACEN:", np.degrees(alpha), "DEC_CEN:", np.degrees(delta), "LONPOLE:", np.degrees(phi))

    print("normalized lonpole:", np.degrees(phi) % 360.0)

    # write a temporary yaml
    temp_yaml = config_dir / f"config_sca_{sca:02d}.yaml"
    with open(temp_yaml, "w") as f:
        yaml.safe_dump(config, f)

    print(f"\n===== Running SCA {sca} =====")
    print(f"Config: {temp_yaml}")

    print(
        f"SCA {sca}",
        f"alpha / raCen={np.degrees(alpha):.6f} deg",
        f"delta / decCen={np.degrees(delta):.6f} deg",
        f"phi / LONPOLE={np.degrees(phi):.6f} deg",
    )

    print("\n--- WCS TEST ---")

    print("\nCD:")
    print("CD1_1 =", config.get("CD1_1"))
    print("CD1_2 =", config.get("CD1_2"))
    print("CD2_1 =", config.get("CD2_1"))
    print("CD2_2 =", config.get("CD2_2"))

    # now we run simulation from imagesim.py, this is all a trial run to see if code works
    run_simulation(str(temp_yaml))
